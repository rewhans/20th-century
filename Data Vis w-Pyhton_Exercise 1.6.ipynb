# %% [markdown]
# # Achievement 1.6: Named Entity Recognition and Country Relationships
#
# This notebook uses Natural Language Processing (NLP) and Named Entity Recognition (NER) to analyze a timeline of 20th-century events. The goal is to extract and filter named entities to identify country-level co-occurrences, and ultimately create a relationship dataset for use in a network visualization in Exercise 1.7.
#
# ## Table of Contents
# 1. [Imports and Setup](#1.-Imports-and-Setup)
# 2. [Text Loading and Preprocessing](#2.-Text-Loading-and-Preprocessing)
# 3. [Named Entity Recognition](#3.-Named-Entity-Recognition)
# 4. [Country Entity Filtering](#4.-Country-Entity-Filtering)
# 5. [Relationship Extraction](#5.-Relationship-Extraction)
# 6. [Observations and Export](#6.-Observations-and-Export)

# %% [markdown]
# ## 1. Imports and Setup

# %%
# Import required libraries
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import matplotlib.pyplot as plt
import networkx as nx
import os
import re

# Download and load spaCy's English NER model
# !python -m spacy download en_core_web_sm
NER = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 6.6 MB/s eta 0:00:02
#      ------- -------------------------------- 2.4/12.8 MB 7.1 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.7/12.8 MB 6.8 MB/s eta 0:00:02
#      --------------- ------------------------ 5.0/12.8 MB 6.7 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 6.6 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 6.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 6.8 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 6.6 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 6.6 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 6.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.22)
# Requirement already satisfied: jinja2 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (78.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2025.6.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.2.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.2.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rewha\anaconda\envs\20th_century\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.2)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## 2. Text Loading and Preprocessing

# %%
# Load and read the 20th-century events text file
with open('20th_century_events.txt', 'r', encoding='utf-8', errors='ignore') as file:
    data = file.read().replace('\n', ' ')

# Minimal cleanup
data = data.replace('U.S.A.', 'United States').replace('\xa0', ' ')

# %% [markdown]
# ### Text Cleaning Observations
#
# - Smart quotes, dashes, and symbols rendered correctly.
# - Replaced "U.S.A." with "United States" for consistency.
# - No encoding issues observed; no further cleaning required.

# %% [markdown]
# ## 3. Named Entity Recognition

# %%
# Run NER on the full text
book = NER(data)

# Optional preview of extracted entities
displacy.render(book[0:2000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     # Key Events
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th Century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   ##
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s  -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  January 1:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TheAustralian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  coloniesfederate.[1] -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edward VIIbecame King
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  afterQueen
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Victoria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's death. -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ThePlatt Amendmentprovides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cuban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  independence in exchange for the withdrawal of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  troops. -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :Emily Hobhousereports on the poor conditions in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  internment camps forBoerwomen and children
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inSouth Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : The assassination ofWilliam McKinleyushered in office Vice
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PresidentTheodore Rooseveltafter McKinley's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  death on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : TheEight-Nation Alliancedefeats theBoxer Rebellion, and imposes heavy financial penalties onChina. -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FirstNobel Prizesawarded
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height:

# %%
# Extract sentences and associated named entities
df_sentences = []

for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent.text, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)
df_sentences.head()
# Out:
#                                             sentence  \
# 0  # Key Events of the 20th Century  ## 1900s  - ...
# 1  - March 2: ThePlatt Amendmentprovides for Cuba...
# 2  - June:Emily Hobhousereports on the poor condi...
# 3  September 6: The assassination ofWilliam McKin...
# 4  FirstNobel Prizesawarded. - December 12:Guglie...
#
#                                             entities
# 0  [# Key Events, the 20th Century, 1900s  -, The...
# 1  [March 2, ThePlatt Amendmentprovides, Cuban, A...
# 2                [June, 45, British, inSouth Africa]
# 3  [September 6, PresidentTheodore Rooseveltafter...
# 4  [FirstNobel Prizesawarded, December 12, Guglie...

# %% [markdown]
# ## 4. Country Entity Filtering

# %%
# Load the country list
country_df = pd.read_csv('country_list.txt', header=None, names=['country_name'])

# Filter named entities using country list
def filter_entity(ent_list, country_df):
    return [ent for ent in ent_list if ent in list(country_df['country_name'])]

df_sentences['country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, country_df))
df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]
df_sentences_filtered.head()
# Out:
#                                               sentence  \
# 29   - March 15–16:Electionsto the newParliament of...
# 31   May 26: First commercialMiddle Easternoilfield...
# 130  May 24:Immigration Act of 1924significantly re...
# 218  August 23: TheMolotov–Ribbentrop Pactbetween G...
# 253                 May:End of World War II in Europe.
#
#                                               entities country_entities
# 29   [March 15–16, Electionsto the newParliament of...         [Europe]
# 31   [May 26, Easternoilfield, June 30, TheTunguska...        [Siberia]
# 130  [May 24, Asia, the Middle East, Southern Europ...           [Asia]
# 218  [August 23, TheMolotov, the Soviet Union, Augu...         [Europe]
# 253                             [World War II, Europe]         [Europe]

# %% [markdown]
# ## 5. Relationship Extraction

# %%
# Define relationships between countries within a 5-sentence window
relationships = []

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i + 5, df_sentences_filtered.index[-1])
    country_list = sum((df_sentences_filtered.loc[i:end_i].country_entities), [])
    
    # Remove consecutive duplicates
    country_unique = [
        country_list[j] for j in range(len(country_list))
        if j == 0 or country_list[j] != country_list[j - 1]
    ]
    
    if len(country_unique) > 1:
        for idx in range(len(country_unique) - 1):
            a = country_unique[idx]
            b = country_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
# Convert relationships into a DataFrame and summarize frequencies
relationship_df = pd.DataFrame(relationships)
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis=1), columns=relationship_df.columns)
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source", "target"], sort=False, as_index=False).sum()
relationship_df.head()
# Out:
#            source            target  value
# 0          Europe           Siberia      4
# 1  United Nations  Western European      3

# %% [markdown]
# ## 6. Observations and Export

# %%
# Save the relationships DataFrame to CSV
relationship_df.to_csv("country_relationships.csv", index=False)

# %% [markdown]
# ### Final Notes
#
# - Only 15 sentences contained recognized country entities, many of which were broad terms (e.g., "Europe", "Asia").
# - spaCy's NER model tended to identify regions and organizations rather than specific countries.
# - As a result, only 7 co-occurrence relationships were extracted.
# - The current output reflects the limitations of the text and the NER model.
#
# If needed for Exercise 1.7, the logic could be expanded to:
# - Include regional aliases and manually map them to countries.
# - Use fuzzy matching or external geopolitics libraries.
#
# For now, results are kept within course scope and reflect proper application of NER and filtering.
